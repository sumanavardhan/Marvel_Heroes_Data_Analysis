# %% [markdown]
# 1. Import required libraries

# %%
import numpy as np 
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# 2. Read the csv

# %%
marvel=pd.read_csv("charcters_stats.csv")

# %% [markdown]
# 3. Show the first record from the csv

# %%
marvel.head(1)
# Out:
#       Name Alignment  Intelligence  Strength  Speed  Durability  Power
# 0  3-D Man      good            50        31     43          32     25  \
#
#    Combat  Total
# 0      52    233

# %% [markdown]
# 4. Show the number of rows and columns

# %%
print(f"The number of rows : {len(marvel)}")
print(f"The number of columns : {len(marvel.columns)}")
# Out:
# The number of rows : 611
# The number of columns : 9

# %% [markdown]
# 5. Find the amount of characters who fall under each alignment, you can use value_counts()

# %%
marvel["Alignment"].value_counts()
# Out:
# Alignment
# good       432
# bad        165
# neutral     11
# Name: count, dtype: int64

# %% [markdown]
# 6. Find only the good alignment characters

# %%
super_heroes = marvel[marvel["Alignment"] == "good"]
super_heroes
# Out:
#                 Name Alignment  Intelligence  Strength  Speed  Durability
# 0            3-D Man      good            50        31     43          32  \
# 1             A-Bomb      good            38       100     17          80
# 2         Abe Sapien      good            88        14     35          42
# 3           Abin Sur      good            50        90     53          64
# 6        Adam Monroe      good            63        10     12         100
# ..               ...       ...           ...       ...    ...         ...
# 604            X-Man      good            88        53     53          95
# 606     Yellowjacket      good            88        10     12          28
# 607  Yellowjacket II      good            50        10     35          28
# 608             Ymir      good            50       100     27         100
# 609          Zatanna      good            75        10     23          28
#
#      Power  Combat  Total
# 0       25      52    233
# ...

# %% [markdown]
# 7. Show only the first five records from the previous bullet point

# %%
super_heroes.head()
# Out:
#           Name Alignment  Intelligence  Strength  Speed  Durability  Power
# 0      3-D Man      good            50        31     43          32     25  \
# 1       A-Bomb      good            38       100     17          80     17
# 2   Abe Sapien      good            88        14     35          42     35
# 3     Abin Sur      good            50        90     53          64     84
# 6  Adam Monroe      good            63        10     12         100     71
#
#    Combat  Total
# 0      52    233
# 1      64    316
# 2      85    299
# 3      65    406
# 6      64    320

# %% [markdown]
# 8. Select the top five heroes with the highest speed who have a good alignment

# %%
top_5_speed = super_heroes.sort_values(by="Speed", ascending=False).head(5)
top_5_speed
# Out:
#                Name Alignment  Intelligence  Strength  Speed  Durability
# 231       Flash III      good            63        10    100          60  \
# 304  Jack of Hearts      good            63        55    100          30
# 295         Impulse      good            50        10    100          60
# 525        Stardust      good            88        85    100         110
# 447     Quicksilver      good            63        28    100          60
#
#      Power  Combat  Total
# 231     83      32    348
# 304     70      30    348
# 295     63      60    343
# 525    100      85    568
# 447     57      56    364

# %%
Highest_speed = super_heroes.nlargest(5,"Speed")
Highest_speed
# Out:
#            Name Alignment  Intelligence  Strength  Speed  Durability  Power
# 85   Black Bolt      good            75        67    100          84    100  \
# 229     Flash I      good            63        10    100          50     57
# 230    Flash II      good            63        10    100          60     66
# 231   Flash III      good            63        10    100          60     83
# 232    Flash IV      good            63        10    100          32     59
#
#      Combat  Total
# 85       56    482
# 229      32    312
# 230      32    331
# 231      32    348
# 232      48    312

# %% [markdown]
# The data is inconsistent .

# %% [markdown]
# 9. Select five heroes with maximum power who have a good alignment

# %%
Maximum_power = super_heroes.nlargest(5,"Power")
Maximum_power
# Out:
#               Name Alignment  Intelligence  Strength  Speed  Durability
# 69   Beta Ray Bill      good            63        80     35          95  \
# 70        Beyonder      good            88       100     23         100
# 85      Black Bolt      good            75        67    100          84
# 129          Cable      good            88        48     23          56
# 185        Deadman      good            50        10     33         100
#
#      Power  Combat  Total
# 69     100      84    457
# 70     100      56    467
# 85     100      56    482
# 129    100      80    395
# 185    100      42    335

# %% [markdown]
# 10. Find out how many superheroes there are with power of 100 with good alignment

# %%
Power_100 = super_heroes[super_heroes["Power"] == 100]
print(f"There are {len(Power_100)} superheroes with power of 100 with good alignment")
# Out:
# There are 33 superheroes with power of 100 with good alignment

# %% [markdown]
# 11. Shape them what you got in point 10

# %%
Power_100.shape
# Out:
# (33, 9)

# %% [markdown]
# 12. Show all records from point 10

# %%
Power_100
# Out:
#                   Name Alignment  Intelligence  Strength  Speed  Durability
# 69       Beta Ray Bill      good            63        80     35          95  \
# 70            Beyonder      good            88       100     23         100
# 85          Black Bolt      good            75        67    100          84
# 129              Cable      good            88        48     23          56
# 185            Deadman      good            50        10     33         100
# 196        Doctor Fate      good            81        16     25          80
# 198     Doctor Strange      good           100        10     12          84
# 204       Dr Manhattan      good            88        32     42          95
# 226          Firestorm      good            50        53     58          56
# 251               Goku      good            56       100     75          90
# 266         Hal Jordan      good            63        90     53          64
# ...

# %% [markdown]
# 13. Retrieve the first five records with max power and has good alignment

# %%
First5=Power_100.head()
First5
# Out:
#               Name Alignment  Intelligence  Strength  Speed  Durability
# 69   Beta Ray Bill      good            63        80     35          95  \
# 70        Beyonder      good            88       100     23         100
# 85      Black Bolt      good            75        67    100          84
# 129          Cable      good            88        48     23          56
# 185        Deadman      good            50        10     33         100
#
#      Power  Combat  Total
# 69     100      84    457
# 70     100      56    467
# 85     100      56    482
# 129    100      80    395
# 185    100      42    335

# %% [markdown]
# 14. Draw a bar plot of all superheroes who are having good alignment and a max power of the top five heroes only , take the same object of point 13, show name and total in plot with green bars

# %%
top5 = First5.sort_values(by="Total", ascending=0)[:5]
top5.plot.bar(x='Name', y='Total', color="green")

plt.title("Top 5 Super Heroes who are having good alignment and a max power")
plt.xlabel("Super Heroes")
plt.xticks(rotation=45)
plt.ylabel("Total")
# Out:
# Text(0, 0.5, 'Total')

# %% [markdown]
# 15. Extract villains who having a bad alignment

# %%
Villains = marvel[marvel["Alignment"] == "bad"]
Villains
# Out:
#                Name Alignment  Intelligence  Strength  Speed  Durability
# 4       Abomination       bad            63        80     53          90  \
# 5           Abraxas       bad            88       100     83          99
# 11       Air-Walker       bad            50        85    100          85
# 16            Amazo       bad            75       100    100         100
# 17             Ammo       bad             1         1      1           1
# ..              ...       ...           ...       ...    ...         ...
# 586            Warp       bad            38        10     23          28
# 590       Weapon XI       bad             1         1      1           1
# 593  Willis Stryker       bad            38        16     23          28
# 605     Yellow Claw       bad             1         1      1           1
# 610            Zoom       bad            50        10    100          28
#
#      Power  Combat  Total
# 4       55      95    436
# 5      100      56    526
# ...

# %% [markdown]
# 16. Show first five records of point 15

# %%
Villains.head()
# Out:
#            Name Alignment  Intelligence  Strength  Speed  Durability  Power
# 4   Abomination       bad            63        80     53          90     55  \
# 5       Abraxas       bad            88       100     83          99    100
# 11   Air-Walker       bad            50        85    100          85    100
# 16        Amazo       bad            75       100    100         100    100
# 17         Ammo       bad             1         1      1           1      0
#
#     Combat  Total
# 4       95    436
# 5       56    526
# 11      40    460
# 16     100    575
# 17       1      5

# %% [markdown]
# 17. Show top five fastest super villains in terms of super speed

# %%
Fastest_Villains = Villains.nlargest(5,"Speed")
Fastest_Villains
# Out:
#                Name Alignment  Intelligence  Strength  Speed  Durability
# 11       Air-Walker       bad            50        85    100          85  \
# 16            Amazo       bad            75       100    100         100
# 535  Superboy-Prime       bad            94       100    100         100
# 610            Zoom       bad            50        10    100          28
# 242     General Zod       bad            94       100     96         100
#
#      Power  Combat  Total
# 11     100      40    460
# 16     100     100    575
# 535    100      85    579
# 610     72      28    288
# 242     94      95    579

# %% [markdown]
# 18. Top five super villains in terms of intelligence

# %%
Intellegent_Villains = Villains.nlargest(5,"Intelligence")
Intellegent_Villains
# Out:
#                 Name Alignment  Intelligence  Strength  Speed  Durability
# 386  Mister Mxyzptlk       bad           113        10     12          14  \
# 29        Apocalypse       bad           100       100     33         100
# 122         Brainiac       bad           100        28     63          90
# 194      Doctor Doom       bad           100        32     20         100
# 315            Joker       bad           100        10     12          56
#
#      Power  Combat  Total
# 386    100      28    277
# 29     100      60    493
# 122     60      75    416
# 194     93      84    429
# 315     22      90    290

# %% [markdown]
# 19. Show who is most dangerous super villain after calculating their total (top 5 only)

# %%
Dangerous_Villains = Villains.sort_values(by="Total", ascending=False).head()
Dangerous_Villains
# Out:
#                Name Alignment  Intelligence  Strength  Speed  Durability
# 535  Superboy-Prime       bad            94       100    100         100  \
# 242     General Zod       bad            94       100     96         100
# 16            Amazo       bad            75       100    100         100
# 203        Dormammu       bad            88        95     83         100
# 201        Doomsday       bad            88        80     67         120
#
#      Power  Combat  Total
# 535    100      85    579
# 242     94      95    579
# 16     100     100    575
# 203    100      80    546
# 201    100      90    545

# %% [markdown]
# 20. Draw a histogram for speed of super heroes having fig size 10.5, provide speed in histogram for only good alignment superheroes, title should be "distribution of speed",xlabel should be "speed"

# %%
plt.figure(figsize= (10,5))
super_heroes = marvel[marvel["Alignment"] == "good"]
sns.histplot(data=super_heroes, x="Speed")
plt.title("Distribution of Speed", fontsize = 15, weight = "bold");

# %% [markdown]
# 21. Draw a histogram for combat of super villains having fig size 10.5, provide combat in histogram for only bad alignment superheroes, title should be "distribution of combat", xlabel should be "combat"

# %%
plt.figure(figsize= (10,5))
villains = marvel[marvel["Alignment"] == "bad"]
sns.histplot(data=Villains, x="Combat")
plt.title("Distribution of Combat", fontsize = 15, weight = "bold");

# %% [markdown]
# Extensions

# %% [markdown]
# 1.How many missing data

# %%
is_null_data = marvel.isnull()
total = is_null_data.sum()
percent = ((total/is_null_data.count())*100)
missing_data = pd.concat([total, percent], axis=1, keys=['Total Missing', 'Percent'])
missing_data = missing_data[missing_data['Total Missing']>0]
missing_data.sort_values(by='Percent', ascending=False)
# Out:
#            Total Missing   Percent
# Alignment              3  0.490998

# %% [markdown]
# 2.Displaying boxplot for alignment and intelligence

# %%
sns.boxplot(data=marvel, x='Alignment', y='Intelligence');

# %% [markdown]
# The average intelligence score for individuals with a good alignment falls within the range of 60-65.
#
# Individuals with a bad alignment have an average intelligence score ranging between 65-70.
#
# Those with a neutral alignment have an average intelligence score also ranging between 65-70.
#
# The skewness in the box plot can be attributed to the larger number of records with intelligence scores below 20. Shown below

# %% [markdown]
# 3.Plot a univariate(Intelligence) distribution along the x axis:

# %%
sns.kdeplot(data=marvel, x="Intelligence")
# Out:
# <Axes: xlabel='Intelligence', ylabel='Density'>

# %% [markdown]
# 4.Displaying Barplots

# %% [markdown]
# Function for barplot(superpowers)

# %%
def  create_bar(col):
    plt.figure(figsize = (10,6))
    temp_df = marvel.groupby("Alignment")[col].mean().round(decimals=2).reset_index()
    ax = sns.barplot(
        data = temp_df,
        x = "Alignment",
        y = col,
        palette = ["#941A00", "#439429", "#1E38AD"]
    )
    plt.title(f"{col} with respect to Alignment", fontsize =  15, weight = "bold");
    for i in ax.containers:
        ax.bar_label(i,)
    plt.show()

# %%
cols = ['Intelligence', 'Strength', 'Speed', 'Durability', 'Power', 'Combat']
for col in cols:
    create_bar(col)

# %% [markdown]
# 5.Showing the distribution of Total (all the powers combined) for the good and the evil.

# %%
#Creating two filters to find good and bad characters.
filterGood=marvel['Alignment'].isin(['good'])
filterBad=marvel['Alignment'].isin(['bad'])

#Creating a figure for 2 plots
f,(ax1,ax2)=plt.subplots(2,1,figsize=(7,7), sharex=True, sharey=True)

#Plot the data and show the distribution
sns.distplot(marvel[filterGood]['Total'],ax=ax1)
ax1.set_ylabel("Good")
sns.distplot(marvel[filterBad]['Total'],ax=ax2)
ax2.set_ylabel("Bad")
# Out:
# C:\Users\batte\AppData\Local\Temp\ipykernel_25940\524724166.py:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(marvel[filterGood]['Total'],ax=ax1)
# C:\Users\batte\AppData\Local\Temp\ipykernel_25940\524724166.py:11: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %% [markdown]
# 6.Character Allignment Piechart

# %%
labels = marvel["Alignment"].value_counts().index
sizes = marvel["Alignment"].value_counts().values
color = ["green","red","blue"]
explode =[0,0,0]
plt.subplots(figsize =(10,10))
plt.pie(sizes, explode = explode ,labels=labels, colors = color,autopct ="%1.1f%%")
plt.title("Percentages of Characters Alignment's")
plt.legend()

# %% [markdown]
#  7.Displaying box plot summarizing the Intelligence, Strength, Speed, Durability, Power, Combat statistics

# %%
sns.boxplot(data=marvel[['Intelligence','Strength','Speed','Durability','Power','Combat']])
plt.ylim(0,150)  #change the scale of y axix
plt.show()

# %% [markdown]
# 8.Displaying violinplot on alignment and total

# %%
plt.subplots(figsize = (20,10))
plt.title('Attack by Type1')
sns.violinplot(x = "Alignment", y = "Total",data = marvel)
plt.show()
